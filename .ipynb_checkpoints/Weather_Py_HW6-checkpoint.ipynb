# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Dependencies and Setup
import requests
import json
from pprint import pprint
from citipy import citipy
import random
import pandas as pd
print(api_key)
# Out:
# bcee9c554ff1dd5700de801663fbdcf4

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?"
cnt=0
latlist=list()
longlist=list()

for o in range(-180,181,20):
    longlist.append(o)
#longlist=[-180,thru-20, 0 ,20 thru 180]

#list of cities
cityset=set()

#list of countries corresponding to the city.
cnylist=list()
#create list of longitudes for use as a random choice

for i in range(-90,90,+2):
#use latitude choice from -90 to +90 and get a city closest to that latitude.
    for j in longlist:
        lat=i
        long=j
        city = citipy.nearest_city(lat, long)
        cityset.add(city.city_name)
        cnylist.append(city.country_code)
print(str(len(cityset)))
print(str(len(cnylist)))
# Out:
# 555
# 1710

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Set query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
#print(api_key)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=bcee9c554ff1dd5700de801663fbdcf4&units=metric&q=

# %%
# Get current weather for all the cities using openweathermapy. 
#Get count variables. 
cntcity=0
cntfail=0
     
# Set up lists 
citylist=list()
cloudiness=list()
temp = list()
cnycode=list()
date=list()
humidity=list()
lat = list()
long=list()
tempmax=list()
windspeed=list()

# Loop through the list of cities and perform a request for weather data on each city.store results in lists. 
for city in cityset:
    #print(str(city))
    cntcity=cntcity+1
    print("Retrieving  data for record " + str(cntcity) + " " + city)
    try:
        weatherdetails = requests.get(query_url + city).json()
        #pprint(weatherdetails)
        citylist.append (weatherdetails["name"])
        cloudiness.append (weatherdetails["clouds"]["all"])
        cnycode.append (weatherdetails["sys"]["country"])
        #datetime=weatherdetails["dt"]
        date.append (weatherdetails["dt"])
        humidity.append (weatherdetails["main"]["humidity"])
        lat.append (weatherdetails["coord"]["lat"])
        long.append (weatherdetails["coord"]["lon"])
        tempmax.append (weatherdetails["main"]["temp_max"])
        windspeed.append (weatherdetails["wind"]["speed"])
    except:
        cntfail +=1
        print("Error in getting data for city " + city)
        print("error code: " + weatherdetails["cod"])
        print("message: " + weatherdetails["message"])

pprint(weatherdetails)        
print("Data Retrieval Complete....")
print("---------------------------------------------------------")
print("Number of cities weather data  not found: " + str(cntfail))
# Out:
# Retrieving  data for record 1 ilulissat
# Retrieving  data for record 2 torbay
# Retrieving  data for record 3 uvalde
# Retrieving  data for record 4 carnarvon
# Retrieving  data for record 5 chase
# Retrieving  data for record 6 kedrovyy
# Retrieving  data for record 7 anuradhapura
# Retrieving  data for record 8 ginda
# Retrieving  data for record 9 kirakira
# Retrieving  data for record 10 koupela
# Retrieving  data for record 11 am timan
# Retrieving  data for record 12 port alfred
# Retrieving  data for record 13 urengoy
# Retrieving  data for record 14 nuevo laredo
# Retrieving  data for record 15 lebu
# Retrieving  data for record 16 waingapu
# Retrieving  data for record 17 uniontown
# Retrieving  data for record 18 mitrofanovka
# Retrieving  data for record 19 osmena
# Retrieving  data for record 20 channel-port aux basques
# Retrieving  data for record 21 burnie
# Retrieving  data for record 22 upernavik
# Retrieving  data for record 23 ewa beach
# Retrieving  data for record 24 beringovskiy
# Retrieving  data for record 25 mombasa
# Retrieving  data for record 26 alamor
# Retrieving  data for record 27 tumannyy
# Error in getting data for city tumannyy
# error code: 404
# message: city not found
# Retrieving  data for record 28 coihaique
# Retrieving  data for record 29 longyearbyen
# Retrieving  data for record 30 puerto escondido
# Retrieving  data for record 31 fernandez
# Retrieving  data for record 32 carutapera
# Retrieving  data for record 33 broken hill
# Retrieving  data for record 34 hualmay
# Retrieving  data for record 35 isla vista
# Retrieving  data for record 36 victoria
# Retrieving  data for record 37 arraial do cabo
# Retrieving  data for record 38 labuhan
# Retrieving  data for record 39 sturgeon falls
# Retrieving  data for record 40 mahebourg
# Retrieving  data for record 41 umzimvubu
# Error in getting data for city umzimvubu
# error code: 404
# message: city not found
# Retrieving  data for record 42 cape coast
# Retrieving  data for record 43 resistencia
# Retrieving  data for record 44 den chai
# Retrieving  data for record 45 poso
# Retrieving  data for record 46 san pedro
# Retrieving  data for record 47 saint-augustin
# Retrieving  data for record 48 nayudupeta
# Retrieving  data for record 49 jiaonan
# Retrieving  data for record 50 barrow
# Retrieving  data for record 51 port-gentil
# Retrieving  data for record 52 kodiak
# Retrieving  data for record 53 aklavik
# Retrieving  data for record 54 vaitupu
# Error in getting data for city vaitupu
# error code: 404
# message: city not found
# Retrieving  data for record 55 erhlin
# Error in getting data for city erhlin
# error code: 404
# message: city not found
# Retrieving  data for record 56 mahbubabad
# Retrieving  data for record 57 bandarbeyla
# Retrieving  data for record 58 tukrah
# Error in getting data for city tukrah
# error code: 404
# message: city not found
# Retrieving  data for record 59 hermanus
# Retrieving  data for record 60 mayor pablo lagerenza
# Retrieving  data for record 61 aripuana
# Retrieving  data for record 62 semey
# Retrieving  data for record 63 kharovsk
# Retrieving  data for record 64 norman wells
# Retrieving  data for record 65 angoche
# Retrieving  data for record 66 yoichi
# Retrieving  data for record 67 bluff
# Retrieving  data for record 68 chicama
# Retrieving  data for record 69 tanete
# Retrieving  data for record 70 oussouye
# Retrieving  data for record 71 sokoni
# Retrieving  data for record 72 leningradskiy
# Retrieving  data for record 73 ruatoria
# Error in getting data for city ruatoria
# error code: 404
# message: city not found
# Retrieving  data for record 74 salvacion
# Retrieving  data for record 75 belushya guba
# Error in getting data for city belushya guba
# error code: 404
# message: city not found
# Retrieving  data for record 76 ndele
# Error in getting data for city ndele
# error code: 404
# message: city not found
# Retrieving  data for record 77 beloha
# Retrieving  data for record 78 lucapa
# Retrieving  data for record 79 redmond
# Retrieving  data for record 80 moose factory
# Retrieving  data for record 81 lyngseidet
# Retrieving  data for record 82 inta
# Retrieving  data for record 83 acarau
# Error in getting data for city acarau
# error code: 404
# message: city not found
# Retrieving  data for record 84 nagai
# Retrieving  data for record 85 ampanihy
# Retrieving  data for record 86 iraucuba
# Retrieving  data for record 87 gangotri
# Error in getting data for city gangotri
# error code: 404
# message: city not found
# Retrieving  data for record 88 bayburt
# Retrieving  data for record 89 bodden town
# Retrieving  data for record 90 souillac
# Retrieving  data for record 91 butaritari
# Retrieving  data for record 92 bang len
# Retrieving  data for record 93 mount isa
# Retrieving  data for record 94 koumac
# Retrieving  data for record 95 hvolsvollur
# Error in getting data for city hvolsvollur
# error code: 404
# message: city not found
# Retrieving  data for record 96 jamestown
# Retrieving  data for record 97 fushe-arrez
# Retrieving  data for record 98 hazorasp
# Retrieving  data for record 99 new norfolk
# Retrieving  data for record 100 montanha
# Retrieving  data for record 101 ormond beach
# Retrieving  data for record 102 mangit
# Retrieving  data for record 103 lerwick
# Retrieving  data for record 104 makakilo city
# Retrieving  data for record 105 tasiilaq
# Retrieving  data for record 106 severo-kurilsk
# Retrieving  data for record 107 pondicherry
# Retrieving  data for record 108 mosquera
# Retrieving  data for record 109 avenal
# Retrieving  data for record 110 ayan
# Retrieving  data for record 111 dingle
# Retrieving  data for record 112 saint-philippe
# Retrieving  data for record 113 kieta
# Retrieving  data for record 114 cabra
# Retrieving  data for record 115 wajir
# Retrieving  data for record 116 grandview
# Retrieving  data for record 117 mogocha
# Retrieving  data for record 118 el triunfo
# Retrieving  data for record 119 palana
# Retrieving  data for record 120 delvine
# Retrieving  data for record 121 kristiinankaupunki
# Error in getting data for city kristiinankaupunki
# error code: 404
# message: city not found
# Retrieving  data for record 122 nizhniy ufaley
# Retrieving  data for record 123 longkou
# Retrieving  data for record 124 severodvinsk
# Retrieving  data for record 125 kamennomostskiy
# Retrieving  data for record 126 kuala kedah
# Retrieving  data for record 127 zhigansk
# Retrieving  data for record 128 bredasdorp
# Retrieving  data for record 129 alyangula
# Retrieving  data for record 130 puerto ayora
# Retrieving  data for record 131 tura
# Retrieving  data for record 132 zharkent
# Retrieving  data for record 133 nelson bay
# Retrieving  data for record 134 payakumbuh
# Retrieving  data for record 135 orlik
# Retrieving  data for record 136 port elizabeth
# Retrieving  data for record 137 rawson
# Retrieving  data for record 138 margate
# Retrieving  data for record 139 karasburg
# Retrieving  data for record 140 rongcheng
# Retrieving  data for record 141 broome
# Retrieving  data for record 142 east london
# Retrieving  data for record 143 taua
# Retrieving  data for record 144 strezhevoy
# Retrieving  data for record 145 gisborne
# Retrieving  data for record 146 benidorm
# Retrieving  data for record 147 tenno
# Retrieving  data for record 148 hithadhoo
# Retrieving  data for record 149 susanville
# Retrieving  data for record 150 te anau
# Retrieving  data for record 151 grand river south east
# Error in getting data for city grand river south east
# error code: 404
# message: city not found
# Retrieving  data for record 152 singkang
# Retrieving  data for record 153 khanu woralaksaburi
# Retrieving  data for record 154 dombarovskiy
# Retrieving  data for record 155 portland
# Retrieving  data for record 156 burriana
# Retrieving  data for record 157 pangnirtung
# Retrieving  data for record 158 mecca
# Retrieving  data for record 159 hamilton
# Retrieving  data for record 160 oum hadjer
# Retrieving  data for record 161 saint george
# Retrieving  data for record 162 hertford
# Retrieving  data for record 163 garissa
# Retrieving  data for record 164 ubinskoye
# Retrieving  data for record 165 methoni
# Retrieving  data for record 166 skelleftea
# Retrieving  data for record 167 bargal
# Error in getting data for city bargal
# error code: 404
# message: city not found
# Retrieving  data for record 168 sun valley
# Retrieving  data for record 169 robe
# Retrieving  data for record 170 doctor arroyo
# Retrieving  data for record 171 saskylakh
# Retrieving  data for record 172 calvinia
# Retrieving  data for record 173 birjand
# Retrieving  data for record 174 scarborough
# Retrieving  data for record 175 chimbote
# Retrieving  data for record 176 pierre
# Retrieving  data for record 177 barentsburg
# Error in getting data for city barentsburg
# error code: 404
# message: city not found
# Retrieving  data for record 178 kanjiza
# Retrieving  data for record 179 sobinka
# Retrieving  data for record 180 volchansk
# Retrieving  data for record 181 kamiiso
# Retrieving  data for record 182 dodge city
# Retrieving  data for record 183 kilindoni
# Retrieving  data for record 184 temascalcingo
# Retrieving  data for record 185 grootfontein
# Retrieving  data for record 186 faanui
# Retrieving  data for record 187 richards bay
# Retrieving  data for record 188 ko samui
# Retrieving  data for record 189 ngunguru
# Retrieving  data for record 190 hilo
# Retrieving  data for record 191 kapaa
# Retrieving  data for record 192 paitan
# Retrieving  data for record 193 crab hill
# Error in getting data for city crab hill
# error code: 404
# message: city not found
# Retrieving  data for record 194 lixourion
# Retrieving  data for record 195 boa vista
# Retrieving  data for record 196 georgetown
# Retrieving  data for record 197 qurayyat
# Error in getting data for city qurayyat
# error code: 404
# message: city not found
# Retrieving  data for record 198 padang
# Retrieving  data for record 199 filadelfia
# Retrieving  data for record 200 punta arenas
# Retrieving  data for record 201 matranovak
# Retrieving  data for record 202 roald
# Retrieving  data for record 203 cayenne
# Retrieving  data for record 204 dikson
# Retrieving  data for record 205 charleston
# Retrieving  data for record 206 vernon
# Retrieving  data for record 207 merauke
# Retrieving  data for record 208 korem
# Retrieving  data for record 209 dori
# Retrieving  data for record 210 ouricuri
# Retrieving  data for record 211 fuyang
# Retrieving  data for record 212 bismarck
# Retrieving  data for record 213 peachland
# Retrieving  data for record 214 toliary
# Error in getting data for city toliary
# error code: 404
# message: city not found
# Retrieving  data for record 215 halalo
# Error in getting data for city halalo
# error code: 404
# message: city not found
# Retrieving  data for record 216 jaguarari
# Retrieving  data for record 217 murray bridge
# Retrieving  data for record 218 lethem
# Retrieving  data for record 219 attawapiskat
# Error in getting data for city attawapiskat
# error code: 404
# message: city not found
# Retrieving  data for record 220 kargasok
# Retrieving  data for record 221 itarantim
# Retrieving  data for record 222 xining
# Retrieving  data for record 223 ponta do sol
# Retrieving  data for record 224 jalu
# Retrieving  data for record 225 laguna
# Retrieving  data for record 226 bengkulu
# Error in getting data for city bengkulu
# error code: 404
# message: city not found
# Retrieving  data for record 227 goderich
# Retrieving  data for record 228 north platte
# Retrieving  data for record 229 marcona
# Error in getting data for city marcona
# error code: 404
# message: city not found
# Retrieving  data for record 230 lowicz
# Retrieving  data for record 231 geraldton
# Retrieving  data for record 232 bartica
# Retrieving  data for record 233 sebastian
# Retrieving  data for record 234 russell
# Retrieving  data for record 235 tarko-sale
# Retrieving  data for record 236 bridlington
# Retrieving  data for record 237 hollins
# Retrieving  data for record 238 rikitea
# Retrieving  data for record 239 korablino
# Retrieving  data for record 240 poum
# Retrieving  data for record 241 ayagoz
# Retrieving  data for record 242 tolaga bay
# Retrieving  data for record 243 umm lajj
# Retrieving  data for record 244 nizhneyansk
# Error in getting data for city nizhneyansk
# error code: 404
# message: city not found
# Retrieving  data for record 245 mnogovershinnyy
# Retrieving  data for record 246 mayo
# Retrieving  data for record 247 devils lake
# Retrieving  data for record 248 san rafael
# Retrieving  data for record 249 mangai
# Retrieving  data for record 250 chuy
# Retrieving  data for record 251 shingu
# Retrieving  data for record 252 vilhena
# Retrieving  data for record 253 serra
# Retrieving  data for record 254 marin
# Retrieving  data for record 255 hasaki
# Retrieving  data for record 256 taolanaro
# Error in getting data for city taolanaro
# error code: 404
# message: city not found
# Retrieving  data for record 257 vestmannaeyjar
# Retrieving  data for record 258 viransehir
# Retrieving  data for record 259 constitucion
# Retrieving  data for record 260 rantauprapat
# Retrieving  data for record 261 turayf
# Retrieving  data for record 262 grand gaube
# Retrieving  data for record 263 anadyr
# Retrieving  data for record 264 gunjur
# Retrieving  data for record 265 mitsukaido
# Retrieving  data for record 266 bambous virieux
# Retrieving  data for record 267 abilene
# Retrieving  data for record 268 abu kamal
# Retrieving  data for record 269 ruteng
# Retrieving  data for record 270 novo aripuana
# Retrieving  data for record 271 inongo
# Retrieving  data for record 272 tawkar
# Error in getting data for city tawkar
# error code: 404
# message: city not found
# Retrieving  data for record 273 salalah
# Retrieving  data for record 274 aventura
# Retrieving  data for record 275 byron bay
# Retrieving  data for record 276 asau
# Error in getting data for city asau
# error code: 404
# message: city not found
# Retrieving  data for record 277 mocuba
# Retrieving  data for record 278 port macquarie
# Retrieving  data for record 279 vaini
# Retrieving  data for record 280 hobart
# Retrieving  data for record 281 yaan
# Retrieving  data for record 282 mar del plata
# Retrieving  data for record 283 ribeira grande
# Retrieving  data for record 284 airai
# Retrieving  data for record 285 uyskoye
# Retrieving  data for record 286 takoradi
# Retrieving  data for record 287 fort saint john
# Error in getting data for city fort saint john
# error code: 404
# message: city not found
# Retrieving  data for record 288 namatanai
# Retrieving  data for record 289 albany
# Retrieving  data for record 290 lumut
# Retrieving  data for record 291 fort nelson
# Retrieving  data for record 292 lima
# Retrieving  data for record 293 rio claro
# Retrieving  data for record 294 olmos
# Retrieving  data for record 295 pavilosta
# Retrieving  data for record 296 narsaq
# Retrieving  data for record 297 peterhead
# Retrieving  data for record 298 cherskiy
# Retrieving  data for record 299 tarakan
# Retrieving  data for record 300 kazalinsk
# Error in getting data for city kazalinsk
# error code: 404
# message: city not found
# Retrieving  data for record 301 zabol
# Retrieving  data for record 302 cidreira
# Retrieving  data for record 303 guerrero negro
# Retrieving  data for record 304 orangeville
# Retrieving  data for record 305 hailar
# Retrieving  data for record 306 verkhnyaya khava
# Retrieving  data for record 307 port hawkesbury
# Retrieving  data for record 308 danilov
# Retrieving  data for record 309 beaverlodge
# Retrieving  data for record 310 woodward
# Retrieving  data for record 311 apaxtla
# Error in getting data for city apaxtla
# error code: 404
# message: city not found
# Retrieving  data for record 312 maarianhamina
# Error in getting data for city maarianhamina
# error code: 404
# message: city not found
# Retrieving  data for record 313 port hueneme
# Retrieving  data for record 314 presidencia roque saenz pena
# Retrieving  data for record 315 fecamp
# Retrieving  data for record 316 kiunga
# Retrieving  data for record 317 atuona
# Retrieving  data for record 318 florence
# Retrieving  data for record 319 sawtell
# Retrieving  data for record 320 tuktoyaktuk
# Retrieving  data for record 321 corralillo
# Retrieving  data for record 322 tungkang
# Error in getting data for city tungkang
# error code: 404
# message: city not found
# Retrieving  data for record 323 los llanos de aridane
# Retrieving  data for record 324 verkhnevilyuysk
# Retrieving  data for record 325 ushuaia
# Retrieving  data for record 326 winneba
# Retrieving  data for record 327 chifeng
# Retrieving  data for record 328 kodino
# Retrieving  data for record 329 matara
# Retrieving  data for record 330 boende
# Retrieving  data for record 331 sentyabrskiy
# Error in getting data for city sentyabrskiy
# error code: 404
# message: city not found
# Retrieving  data for record 332 cabo san lucas
# Retrieving  data for record 333 ajdabiya
# Retrieving  data for record 334 clyde river
# Retrieving  data for record 335 iranshahr
# Retrieving  data for record 336 northam
# Retrieving  data for record 337 sitka
# Retrieving  data for record 338 wulanhaote
# Error in getting data for city wulanhaote
# error code: 404
# message: city not found
# Retrieving  data for record 339 yendi
# Retrieving  data for record 340 egvekinot
# Retrieving  data for record 341 rosarito
# Retrieving  data for record 342 simbahan
# Retrieving  data for record 343 morag
# Retrieving  data for record 344 emba
# Retrieving  data for record 345 kodinsk
# Retrieving  data for record 346 kurara
# Retrieving  data for record 347 allonnes
# Retrieving  data for record 348 faya
# Retrieving  data for record 349 wieliczka
# Retrieving  data for record 350 mount gambier
# Retrieving  data for record 351 palabuhanratu
# Error in getting data for city palabuhanratu
# error code: 404
# message: city not found
# Retrieving  data for record 352 jitauna
# Retrieving  data for record 353 christchurch
# Retrieving  data for record 354 skagastrond
# Error in getting data for city skagastrond
# error code: 404
# message: city not found
# Retrieving  data for record 355 ron phibun
# Retrieving  data for record 356 zhangye
# Retrieving  data for record 357 tuatapere
# Retrieving  data for record 358 pemba
# Retrieving  data for record 359 biltine
# Retrieving  data for record 360 goba
# Retrieving  data for record 361 manicaragua
# Retrieving  data for record 362 dali
# Retrieving  data for record 363 adwa
# Retrieving  data for record 364 san quintin
# Retrieving  data for record 365 hovd
# Retrieving  data for record 366 saint-francois
# Retrieving  data for record 367 isangel
# Retrieving  data for record 368 erie
# Retrieving  data for record 369 fortuna
# Retrieving  data for record 370 shache
# Retrieving  data for record 371 provideniya
# Retrieving  data for record 372 bogorodskoye
# Retrieving  data for record 373 mashhad
# Retrieving  data for record 374 black river
# Retrieving  data for record 375 yellowknife
# Retrieving  data for record 376 baixa grande
# Retrieving  data for record 377 lexington
# Retrieving  data for record 378 tshikapa
# Retrieving  data for record 379 nouadhibou
# Retrieving  data for record 380 pisco
# Retrieving  data for record 381 ancud
# Retrieving  data for record 382 barbastro
# Retrieving  data for record 383 tres arroyos
# Retrieving  data for record 384 chaoyang
# Retrieving  data for record 385 brandon
# Retrieving  data for record 386 wahran
# Error in getting data for city wahran
# error code: 404
# message: city not found
# Retrieving  data for record 387 tecoanapa
# Retrieving  data for record 388 lindi
# Retrieving  data for record 389 polunochnoye
# Retrieving  data for record 390 sovetskaya gavan
# Retrieving  data for record 391 kui buri
# Retrieving  data for record 392 portobelo
# Retrieving  data for record 393 sao joao da barra
# Retrieving  data for record 394 rundu
# Retrieving  data for record 395 deputatskiy
# Retrieving  data for record 396 primore
# Error in getting data for city primore
# error code: 404
# message: city not found
# Retrieving  data for record 397 luena
# Retrieving  data for record 398 coquimbo
# Retrieving  data for record 399 dakar
# Retrieving  data for record 400 chabahar
# Retrieving  data for record 401 lishui
# Retrieving  data for record 402 milkovo
# Retrieving  data for record 403 weligama
# Retrieving  data for record 404 evensk
# Retrieving  data for record 405 guarare
# Retrieving  data for record 406 porto novo
# Retrieving  data for record 407 nizhniy tagil
# Retrieving  data for record 408 waraseoni
# Retrieving  data for record 409 novoleushkovskaya
# Retrieving  data for record 410 port hardy
# Retrieving  data for record 411 avarua
# Retrieving  data for record 412 pedernales
# Retrieving  data for record 413 palu
# Retrieving  data for record 414 sur
# Retrieving  data for record 415 simao
# Retrieving  data for record 416 bosobolo
# Retrieving  data for record 417 petropavlovsk-kamchatskiy
# Retrieving  data for record 418 vanimo
# Retrieving  data for record 419 krasnoyarskiy
# Retrieving  data for record 420 tonneins
# Retrieving  data for record 421 armacao dos buzios
# Error in getting data for city armacao dos buzios
# error code: 404
# message: city not found
# Retrieving  data for record 422 skjervoy
# Retrieving  data for record 423 bokspits
# Error in getting data for city bokspits
# error code: 404
# message: city not found
# Retrieving  data for record 424 galle
# Retrieving  data for record 425 the valley
# Retrieving  data for record 426 whitley bay
# Retrieving  data for record 427 cape town
# Retrieving  data for record 428 manuk mangkaw
# Retrieving  data for record 429 awjilah
# Retrieving  data for record 430 chiang rai
# Retrieving  data for record 431 reconquista
# Retrieving  data for record 432 iqaluit
# Retrieving  data for record 433 la palma
# Retrieving  data for record 434 jiuquan
# Retrieving  data for record 435 merced
# Retrieving  data for record 436 mabaruma
# Retrieving  data for record 437 akropong
# Retrieving  data for record 438 kpandae
# Retrieving  data for record 439 khonuu
# Error in getting data for city khonuu
# error code: 404
# message: city not found
# Retrieving  data for record 440 pawayan
# Retrieving  data for record 441 adrar
# Retrieving  data for record 442 manaus
# Retrieving  data for record 443 the pas
# Retrieving  data for record 444 nikolskoye
# Retrieving  data for record 445 dawson creek
# Retrieving  data for record 446 waipawa
# Retrieving  data for record 447 tessalit
# Retrieving  data for record 448 mataura
# Retrieving  data for record 449 kirkland lake
# Retrieving  data for record 450 kaka
# Retrieving  data for record 451 hay river
# Retrieving  data for record 452 sakakah
# Error in getting data for city sakakah
# error code: 404
# message: city not found
# Retrieving  data for record 453 sidi ali
# Retrieving  data for record 454 pozo colorado
# Retrieving  data for record 455 umea
# Retrieving  data for record 456 kiruna
# Retrieving  data for record 457 nanortalik
# Retrieving  data for record 458 brae
# Retrieving  data for record 459 aflu
# Error in getting data for city aflu
# error code: 404
# message: city not found
# Retrieving  data for record 460 shimoda
# Retrieving  data for record 461 saldanha
# Retrieving  data for record 462 taixing
# Retrieving  data for record 463 sinait
# Retrieving  data for record 464 taybad
# Retrieving  data for record 465 bageshwar
# Retrieving  data for record 466 vila franca do campo
# Retrieving  data for record 467 chunskiy
# Retrieving  data for record 468 ust-nera
# Retrieving  data for record 469 bethel
# Retrieving  data for record 470 veinticinco de mayo
# Retrieving  data for record 471 raudeberg
# Retrieving  data for record 472 honiara
# Retrieving  data for record 473 vysokogornyy
# Retrieving  data for record 474 addanki
# Retrieving  data for record 475 mul
# Retrieving  data for record 476 trabzon
# Retrieving  data for record 477 witu
# Retrieving  data for record 478 kidal
# Retrieving  data for record 479 pawai
# Retrieving  data for record 480 qaanaaq
# Retrieving  data for record 481 san andres
# Retrieving  data for record 482 pandan niog
# Retrieving  data for record 483 viedma
# Retrieving  data for record 484 antofagasta
# Retrieving  data for record 485 santa maria
# Retrieving  data for record 486 luderitz
# Retrieving  data for record 487 cochrane
# Retrieving  data for record 488 angouleme
# Retrieving  data for record 489 esmeraldas
# Retrieving  data for record 490 khatanga
# Retrieving  data for record 491 almaznyy
# Retrieving  data for record 492 amderma
# Error in getting data for city amderma
# error code: 404
# message: city not found
# Retrieving  data for record 493 qinhuangdao
# Retrieving  data for record 494 cap malheureux
# Retrieving  data for record 495 tulun
# Retrieving  data for record 496 haines junction
# Retrieving  data for record 497 nacala
# Retrieving  data for record 498 yunjinghong
# Error in getting data for city yunjinghong
# error code: 404
# message: city not found
# Retrieving  data for record 499 tazovskiy
# Retrieving  data for record 500 aksu
# Retrieving  data for record 501 acapulco
# Retrieving  data for record 502 panzhihua
# Retrieving  data for record 503 saurimo
# Retrieving  data for record 504 high point
# Retrieving  data for record 505 svetlaya
# Retrieving  data for record 506 naze
# Retrieving  data for record 507 klyuchi
# Retrieving  data for record 508 moyale
# Retrieving  data for record 509 louisbourg
# Error in getting data for city louisbourg
# error code: 404
# message: city not found
# Retrieving  data for record 510 abomsa
# Error in getting data for city abomsa
# error code: 404
# message: city not found
# Retrieving  data for record 511 illoqqortoormiut
# Error in getting data for city illoqqortoormiut
# error code: 404
# message: city not found
# Retrieving  data for record 512 gao
# Retrieving  data for record 513 gold coast
# Retrieving  data for record 514 valvedditturai
# Retrieving  data for record 515 gobabis
# Retrieving  data for record 516 east wenatchee bench
# Retrieving  data for record 517 solnechnyy
# Retrieving  data for record 518 moron
# Retrieving  data for record 519 davila
# Retrieving  data for record 520 tateyama
# Retrieving  data for record 521 binga
# Retrieving  data for record 522 ergani
# Retrieving  data for record 523 nhulunbuy
# Retrieving  data for record 524 benghazi
# Retrieving  data for record 525 leh
# Retrieving  data for record 526 port hedland
# Retrieving  data for record 527 grimari
# Error in getting data for city grimari
# error code: 404
# message: city not found
# Retrieving  data for record 528 karauzyak
# Error in getting data for city karauzyak
# error code: 404
# message: city not found
# Retrieving  data for record 529 rocha
# Retrieving  data for record 530 dunedin
# Retrieving  data for record 531 kaitangata
# Retrieving  data for record 532 castro
# Retrieving  data for record 533 samusu
# Error in getting data for city samusu
# error code: 404
# message: city not found
# Retrieving  data for record 534 dauphin
# Retrieving  data for record 535 nerchinskiy zavod
# Retrieving  data for record 536 shalakusha
# Retrieving  data for record 537 kosjeric
# Retrieving  data for record 538 buala
# Retrieving  data for record 539 pankrushikha
# Retrieving  data for record 540 codrington
# Retrieving  data for record 541 robertson
# Retrieving  data for record 542 parana
# Retrieving  data for record 543 esperance
# Retrieving  data for record 544 borba
# Retrieving  data for record 545 aranos
# Retrieving  data for record 546 sarkand
# Retrieving  data for record 547 rungata
# Error in getting data for city rungata
# error code: 404
# message: city not found
# Retrieving  data for record 548 bubaque
# Retrieving  data for record 549 khani
# Retrieving  data for record 550 mys shmidta
# Error in getting data for city mys shmidta
# error code: 404
# message: city not found
# Retrieving  data for record 551 dongkan
# Retrieving  data for record 552 busselton
# Retrieving  data for record 553 thompson
# Retrieving  data for record 554 mikhaylovskoye
# Retrieving  data for record 555 ostrovnoy
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 68.05, 'lon': 39.51},
#  'dt': 1559750468,
#  'id': 556268,
#  'main': {'grnd_level': 1002.22,
#           'humidity': 65,
#           'pressure': 1017.52,
#           'sea_level': 1017.52,
#           'temp': 8.39,
#           'temp_max': 8.39,
#           'temp_min': 8.39},
#  'name': 'Ostrovnoy',
#  'sys': {'country': 'RU', 'message': 0.0055, 'sunrise': 0, 'sunset': 0},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 333.346, 'speed': 8.09}}
# Data Retrieval Complete....
# ---------------------------------------------------------
# Number of cities weather data  not found: 52

# %%
print(len(citylist))
print(len(cloudiness))
print(len(tempmax))
print(len(humidity))
print(len(lat))
# Out:
# 503
# 503
# 503
# 503
# 503

# %%
#place results into a dictionary and convert to a dataframe. 
weatherdict=dict()
weatherdict={"City":citylist,"Cloudiness":cloudiness,"Country_code":cnycode,"Date":date,
             "Humidity":humidity,"Latitude":lat,"Longitude":long,"Max_temp":tempmax,
             "Wind_speed":windspeed}
#print(len(weatherdict))
weather_df = pd.DataFrame(weatherdict)
weather_df.tail(10)
# Out:
#                City  Cloudiness Country_code        Date  Humidity  Latitude  \
# 493           Borba          20           PT  1559750466        28     38.81
# 494          Aranos           0           NA  1559750466         9    -24.14
# 495         Sarkand          51           KZ  1559750466        44     45.41
# 496         Bubaque          27           GW  1559750466        84     11.28
# 497           Khani          75           GE  1559750467        65     41.96
# 498         Dongkan         100           CN  1559750467        67     34.00
# 499       Busselton         100           AU  1559750467        22    -33.64
# 500        Thompson          75           CA  1559750467        82     55.74
# 501  Mikhaylovskoye          75           RU  1559750467        64     43.10
# 502       Ostrovnoy           8           RU  1559750468        65     68.05
#
#      Longitude  Max_temp  Wind_speed
# 493      -7.46     23.00        6.70
# 494      19.11     25.09        0.81
# 495      79.91     22.19        4.64
# 496     -15.83     26.29        5.08
# 497      42.96     28.00        2.60
# 498     119.83     23.89        6.80
# 499     115.35     17.78       12.27
# 500     -97.86     13.00        2.10
# 501      44.64     23.89        5.00
# 502      39.51      8.39        8.09

# %%
#Save weather data in a csv file for future reference and use. 
weather_df.to_csv("weatherdata.csv",index=False,header=True)
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 9 columns):
# City            503 non-null object
# Cloudiness      503 non-null int64
# Country_code    503 non-null object
# Date            503 non-null int64
# Humidity        503 non-null int64
# Latitude        503 non-null float64
# Longitude       503 non-null float64
# Max_temp        503 non-null float64
# Wind_speed      503 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 35.4+ KB

# %%
#Import dependencies for plotting.
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
x_axis=weather_df["Latitude"]
y_axis_maxtemp=weather_df["Max_temp"]
y_axis_humidity=weather_df["Humidity"]
y_axis_cloudiness = weather_df["Cloudiness"]
y_axis_Windspeed = weather_df["Wind_speed"]

# %%
#Review cities that have temperature greater than 28 deg C.
weather_df.loc[weather_df["Max_temp"] >= 38]
#weather_df_sortedbytemp = weather_df.sort("Max_temp",axis=1,ascending=False,inplace=False)
#weather_df_sortedbytemp.head(10)
# Out:
#            City  Cloudiness Country_code        Date  Humidity  Latitude  \
# 9       Koupela           0           BF  1559750361        23     12.18
# 51   Mahbubabad          60           IN  1559750370        24     17.62
# 144       Mecca          98           SA  1559750140        19     21.43
# 146  Oum Hadjer          75           TD  1559750387        21     13.30
# 191        Dori          35           BF  1559750396        22     14.03
# 236      Turayf          75           SA  1559750407        14     31.68
# 243   Abu Kamal           3           SY  1559750408        12     34.45
# 302   Iranshahr           0           IR  1559750425         8     27.21
# 305       Yendi          18           GH  1559750430        27      9.45
# 312      Kurara          60           IN  1559750431        10     25.98
# 323     Biltine          90           TD  1559750434        16     14.53
# 370   Waraseoni          52           IN  1559750443        12     21.76
# 399     Pawayan           0           IN  1559750448        13     28.07
# 400       Adrar           2           DZ  1559750448         6     27.87
# 406    Tessalit          10           ML  1559750449         5     20.20
# 432         Mul          81           IN  1559750454        14     20.07
# 435       Kidal          80           ML  1559750454         7     18.44
# 436       Pawai           2           IN  1559750454        11     24.27
# 464         Gao          40           ML  1559750461         6     16.28
#
#      Longitude  Max_temp  Wind_speed
# 9        -0.35     39.39        2.09
# 51       80.02     39.69        3.38
# 144      39.83     40.79       10.06
# 146      19.70     40.59        3.53
# 191      -0.03     39.79        3.67
# 236      38.65     38.00        3.10
# 243      40.92     39.09        3.52
# 302      60.69     39.00        5.10
# 305       0.00     39.99        1.27
# 312      79.99     45.09        2.10
# 323      20.93     41.49        6.31
# 370      80.05     39.69        1.61
# 399      80.10     40.29        3.22
# 400      -0.29     41.00        6.20
# 406       1.01     41.49        4.46
# 432      79.68     42.49        2.23
# 435       1.41     41.49        4.72
# 436      80.17     41.99        2.43
# 464      -0.04     41.99        2.49

# %%
#Plot Latitude vs Maximum Temp(C)
sns.regplot(x_axis, y_axis_maxtemp, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label="Latitude vs Max temperature(C)", 
            color=None,marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title("Latitude vs Max temperature(C) Date: 06/05/2019 ")
plt.grid()
plt.xlim(-65,85)
plt.ylim(-10,50)
plt.ylabel("Maximum Temp in C")
plt.savefig("latvsMaxtemp.png")

# %%
#Plot of latitude vs Humidity
sns.regplot(x_axis, y_axis_humidity, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color="g", 
            marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title("Latitude vs Humidity, Date: 06/05/2019 ")
plt.xlim(-65,85)
plt.ylim(-0,100)
plt.ylabel("Humidity % ")
plt.savefig("latvsHumidity.png")

# %%
#Plot of latitude vs Cloudiness
sns.regplot(x_axis, y_axis_cloudiness, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color="grey", 
            marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title("Latitude vs Cloudiness, Date: 06/05/2019 ")
plt.xlim(-65,85)
plt.ylim(-5,100)
plt.ylabel("Cloudiness ")
plt.savefig("latvsCloudiness.png")

# %%
#Latitude vs windspeed
sns.regplot(x_axis, y_axis_Windspeed, data=None, x_estimator=None, x_bins=None, x_ci='ci', 
            scatter=True, fit_reg=False, ci=95, n_boot=1000, units=None, order=1, 
            logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, 
            truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color="cyan", 
            marker='+', scatter_kws=None, line_kws=None, ax=None)
plt.title("Latitude vs Wind speed, Date: 06/05/2019 ")
plt.grid()
plt.xlim(-65,85)
plt.ylim(-0,20)
plt.ylabel("Wind Speed (km/hr) ")
plt.savefig("latvswindspeed.png")

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=200)
lngs = np.random.uniform(low=-180.000, high=180.000, size=200)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 142

# %%
print(api_key)
# Out:
# bcee9c554ff1dd5700de801663fbdcf4

# %%
print(cities)
# Out:
# ['bandarbeyla', 'hobart', 'pangnirtung', 'carnarvon', 'marang', 'alekseyevskaya', 'motygino', 'tuktoyaktuk', 'adrar', 'pevek', 'rikitea', 'hilo', 'dikson', 'port elizabeth', 'torbay', 'kapaa', 'anadyr', 'san patricio', 'belushya guba', 'orzhytsya', 'atuona', 'upernavik', 'khasan', 'yellowknife', 'koindu', 'panjab', 'punta arenas', 'ushuaia', 'shimoda', 'souillac', 'bredasdorp', 'tsihombe', 'cidreira', 'barrow', 'srandakan', 'avarua', 'santa rosa', 'cay', 'codajas', 'mahebourg', 'bluff', 'santo antonio do ica', 'antofagasta', 'zhigansk', 'port alfred', 'barentsburg', 'brownsville', 'portland', 'bubaque', 'kadoma', 'new norfolk', 'tasiilaq', 'mataura', 'lianzhou', 'sao joao da barra', 'narsaq', 'toguchin', 'lebu', 'taoudenni', 'krasnoznamensk', 'qaanaaq', 'vaitupu', 'paamiut', 'pontes e lacerda', 'te anau', 'dunkirk', 'saint-philippe', 'trzcianka', 'karratha', 'mutare', 'boca do acre', 'namibe', 'xinmin', 'bogen', 'illoqqortoormiut', 'vaini', 'cabo san lucas', 'almaznyy', 'piopio', 'port hedland', 'port-de-bouc', 'busselton', 'san cristobal', 'rusape', 'hofn', 'butaritari', 'thompson', 'praia da vitoria', 'ahuimanu', 'ulladulla', 'lysyye gory', 'sao filipe', 'turukhansk', 'angoche', 'avera', 'martorell', 'smithers', 'follonica', 'taolanaro', 'castro', 'hasaki', 'luang prabang', 'cape town', 'coari', 'albany', 'alice springs', 'ternate', 'illapel', 'kurilsk', 'mar del plata', 'college', 'ribeira grande', 'puerto ayora', 'megion', 'tuatapere', 'lamar', 'douglas', 'paita', 'resistencia', 'bagan', 'ostrovnoy', 'pousat', 'alofi', 'vila franca do campo', 'cap malheureux', 'kamaishi', 'morant bay', 'gayeri', 'hithadhoo', 'belen', 'geraldton', 'tautira', 'northam', 'sambava', 'shingu', 'kalabo', 'xining', 'waipawa', 'cherskiy', 'alcudia', 'bushehr', 'noumea']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.
